# %% [markdown]
# # Pandas, Basic Operations

# %%
#import Pandas Library
import pandas as pd

# %%
# Create DataFrame
df1 = pd.DataFrame({"a" : [4, 5, 6],
                   "b" : [7, 8, 9],
                   "c" : [10, 11, 12]},
                  index = [1, 2, 3])

# %%
#print DataFrame
df1
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
# Reshaping the Data  (Gather Columns into rows)
df2 = pd.melt(df1)

# %%
df2
# Out:
#   variable  value
# 0        a      4
# 1        a      5
# 2        a      6
# 3        b      7
# 4        b      8
# 5        b      9
# 6        c     10
# 7        c     11
# 8        c     12

# %%
#Read the Data from CSV file into a DataFrame
df = pd.read_csv('Diabetes_Data.csv')

# %%
# check the data for the first 5 rows  
df.head(5)
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
# Select last 5 rows.
df.tail(5)
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 763           10      101         76       48      180  32.9  0.171   63
# 764            2      122         70       27        0  36.8  0.340   27
# 765            5      121         72       23      112  26.2  0.245   30
# 766            1      126         60        0        0  30.1  0.349   47
# 767            1       93         70       31        0  30.4  0.315   23
#
#      diabetes
# 763         0
# 764         0
# 765         0
# 766         1
# 767         0

# %%
# Number of Rows and columns of the DataFrame
print('Dimensions : {} Rows and {} columns '.format(df.shape[0], df.shape[1]))
# Out:
# Dimensions : 768 Rows and 9 columns

# %%
# Randomly select n rows
df.sample(10)
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 51             1      101         50       15       36  24.2  0.526   26
# 224            1      100         66       15       56  23.6  0.666   26
# 745           12      100         84       33      105  30.0  0.488   46
# 233            4      122         68        0        0  35.0  0.394   29
# 480            3      158         70       30      328  35.5  0.344   35
# 49             7      105          0        0        0   0.0  0.305   24
# 625            4       90         88       47       54  37.7  0.362   29
# 145            0      102         75       23        0   0.0  0.572   21
# 38             2       90         68       42        0  38.2  0.503   27
# 334            1       95         60       18       58  23.9  0.260   22
#
#      diabetes
# 51          0
# 224         0
# 745         0
# 233         0
# 480         1
# 49          0
# 625         0
# 145         0
# 38          1
# ...

# %%
# select rows ( for all columns) by Position
df.iloc[2:4]
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
#
#    diabetes
# 2         1
# 3         0

# %%
# select specific columns only
df[['glucose','insulin','age']]
# Out:
#      glucose  insulin  age
# 0        148        0   50
# 1         85        0   31
# 2        183        0   32
# 3         89       94   21
# 4        137      168   33
# 5        116        0   30
# 6         78       88   26
# 7        115        0   29
# 8        197      543   53
# 9        125        0   54
# 10       110        0   30
# 11       168        0   34
# 12       139        0   57
# 13       189      846   59
# 14       166      175   51
# 15       100        0   32
# 16       118      230   31
# 17       107        0   31
# 18       103       83   33
# 19       115       96   32
# 20       126      235   27
# 21        99        0   50
# 22       196        0   41
# 23       119        0   29
# 24       143      146   51
# 25       125      115   41
# 26       147        0   43
# 27        97      140   22
# 28       145      110   57
# 29       117        0   38
# ..       ...      ...  ...
# 738       99      160   21
# 739      102        0   42
# ...

# %%
# select all rows for specific range of columns
df.loc[:, 'glucose' : 'age']
# Out:
#      glucose  diastolic  triceps  insulin   bmi    dpf  age
# 0        148         72       35        0  33.6  0.627   50
# 1         85         66       29        0  26.6  0.351   31
# 2        183         64        0        0  23.3  0.672   32
# 3         89         66       23       94  28.1  0.167   21
# 4        137         40       35      168  43.1  2.288   33
# 5        116         74        0        0  25.6  0.201   30
# 6         78         50       32       88  31.0  0.248   26
# 7        115          0        0        0  35.3  0.134   29
# 8        197         70       45      543  30.5  0.158   53
# 9        125         96        0        0   0.0  0.232   54
# 10       110         92        0        0  37.6  0.191   30
# 11       168         74        0        0  38.0  0.537   34
# 12       139         80        0        0  27.1  1.441   57
# 13       189         60       23      846  30.1  0.398   59
# 14       166         72       19      175  25.8  0.587   51
# ...

# %%
# count the number of rows with Unique values in a column
df['diabetes'].value_counts()
# Out:
# 0    500
# 1    268
# Name: diabetes, dtype: int64

# %%
# Number of Distinct values in a column
df['diabetes'].nunique()
# Out:
# 2

# %%
# Number of Rows
len(df)
# Out:
# 768

# %%
# Descprictive stats for each column
df.describe()
# Out:
#        pregnancies     glucose   diastolic     triceps     insulin  \
# count   768.000000  768.000000  768.000000  768.000000  768.000000
# mean      3.845052  120.894531   69.105469   20.536458   79.799479
# std       3.369578   31.972618   19.355807   15.952218  115.244002
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000   62.000000    0.000000    0.000000
# 50%       3.000000  117.000000   72.000000   23.000000   30.500000
# 75%       6.000000  140.250000   80.000000   32.000000  127.250000
# max      17.000000  199.000000  122.000000   99.000000  846.000000
#
#               bmi         dpf         age    diabetes
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
# DataFrame information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# pregnancies    768 non-null int64
# glucose        768 non-null int64
# diastolic      768 non-null int64
# triceps        768 non-null int64
# insulin        768 non-null int64
# bmi            768 non-null float64
# dpf            768 non-null float64
# age            768 non-null int64
# diabetes       768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#Drop Rows with column having NA (null)
#df.dropna()

#Replace NA values with any
#df.fillna(5)

#Note - No Null or NA values present in this dataset.

# %%
# SORTING : sorted by the value of one of the variables (columns). 
df.sort_values(by = 'glucose' , ascending=True).head(5)
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 75             1        0         48       20        0  24.7  0.140   22
# 502            6        0         68       41        0  39.0  0.727   41
# 349            5        0         80       32        0  41.0  0.346   37
# 342            1        0         68       35        0  32.0  0.389   22
# 182            1        0         74       20       23  27.7  0.299   21
#
#      diabetes
# 75          0
# 502         1
# 349         1
# 342         0
# 182         0

# %%
# Apply Function .. To apply functions to each column.
#Also need NumPy for some operations... So import it
import numpy as np

df.apply(np.max)
# Out:
# pregnancies     17.00
# glucose        199.00
# diastolic      122.00
# triceps         99.00
# insulin        846.00
# bmi             67.10
# dpf              2.42
# age             81.00
# diabetes         1.00
# dtype: float64

# %%
#Group by :  df.groupby(by=grouping_columns)[columns_to_show].function()
df.groupby(by = 'pregnancies').agg(np.mean)
# Out:
#                 glucose  diastolic    triceps     insulin        bmi  \
# pregnancies
# 0            123.000000  67.153153  22.270270   81.675676  34.290090
# 1            112.748148  67.792593  24.437037   98.674074  31.372593
# 2            110.796117  63.252427  21.601942   85.844660  30.583495
# 3            123.586667  66.586667  20.080000   87.453333  30.425333
# 4            125.117647  70.029412  15.882353   69.441176  32.141176
# 5            118.859649  76.210526  17.385965   57.298246  33.192982
# 6            120.800000  68.420000  17.640000   63.580000  30.290000
# 7            136.444444  70.777778  20.288889   84.466667  32.631111
# 8            131.736842  75.184211  17.315789   92.815789  31.568421
# 9            131.392857  77.892857  20.892857   62.428571  31.707143
# 10           120.916667  70.208333  15.708333   34.791667  30.641667
# 11           126.454545  74.181818  21.727273   65.454545  38.563636
# ...

# %%
df.groupby(['pregnancies'])['glucose', 'bmi'].agg(np.max)
# Out:
#              glucose   bmi
# pregnancies
# 0                198  67.1
# 1                199  55.0
# 2                197  45.5
# 3                193  57.3
# 4                197  48.3
# 5                189  52.9
# 6                195  46.2
# 7                196  50.0
# 8                197  47.9
# 9                184  45.4
# 10               179  45.6
# 11               155  52.3
# 12               151  41.8
# 13               158  43.4
# 14               175  36.6
# 15               136  37.1
# 17               163  40.9

# %%
#DROP 
#Column Delete
#To delete columns or rows, use the drop method, passing the required indexes and the axis parameter (1 if you delete columns, and nothing or 0 if you delete rows). 
#The inplace argument tells whether to change the original DataFrame. 
#With inplace=False, the drop method doesn't change the existing DataFrame and returns a new one with dropped rows or columns. 
#With inplace=True, it alters the DataFrame.
df.drop(['triceps','dpf'], axis=1, inplace=False).head(5)
# Out:
#    pregnancies  glucose  diastolic  insulin   bmi  age  diabetes
# 0            6      148         72        0  33.6   50         1
# 1            1       85         66        0  26.6   31         0
# 2            8      183         64        0  23.3   32         1
# 3            1       89         66       94  28.1   21         0
# 4            0      137         40      168  43.1   33         1

# %%
#Rows Delete
df.drop([0,1], axis=0, inplace=False).head(5)
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
# 5            5      116         74        0        0  25.6  0.201   30
# 6            3       78         50       32       88  31.0  0.248   26
#
#    diabetes
# 2         1
# 3         0
# 4         1
# 5         0
# 6         1
